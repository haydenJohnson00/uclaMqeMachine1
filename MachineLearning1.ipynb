# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv('/content/gdrive/MyDrive/MachineLearning/US_honey_dataset_updated.csv')

# %%
plt.figure(figsize = (12,5))
plt.plot(df['average_price'])
plt.title('Average Price of Honey Bee Production')
plt.xlabel('Number of Observations')
plt.ylabel('Average Price')
plt.grid()
plt.show()

# %% [markdown]
# The average price of honey bee production has increased over time and then dramatically fell off
